# %%
import scrape_attendance as sa
import pandas as pd

# %%
att = sa.get_attendance_all_levels(2022)
att.sample(10)
# Out:
#                                    link gameType season              gameDate  \
# gamePk
# 664808  /api/v1.1/game/664808/feed/live        R   2022  2022-06-18T22:05:00Z
# 673752  /api/v1.1/game/673752/feed/live        R   2022  2022-04-27T22:35:00Z
# 664277  /api/v1.1/game/664277/feed/live        R   2022  2022-04-17T17:05:00Z
# 671193  /api/v1.1/game/671193/feed/live        R   2022  2022-05-22T21:05:00Z
# 669856  /api/v1.1/game/669856/feed/live        R   2022  2022-06-12T21:05:00Z
# 705768  /api/v1.1/game/705768/feed/live        R   2022  2022-05-16T00:00:00Z
# 671847  /api/v1.1/game/671847/feed/live        R   2022  2022-06-05T18:00:00Z
# 669381  /api/v1.1/game/669381/feed/live        R   2022  2022-06-02T23:05:00Z
# 665920  /api/v1.1/game/665920/feed/live        R   2022  2022-05-17T22:35:00Z
# 672988  /api/v1.1/game/672988/feed/live        R   2022  2022-04-10T17:05:00Z
#
#        officialDate  isTie  gameNumber  publicFacing doubleHeader gamedayType  \
# gamePk
# ...
