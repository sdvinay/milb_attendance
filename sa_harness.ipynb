# %%
import scrape_attendance as sa
import pandas as pd

# %%
att = sa.get_attendance_all_levels(2022)
att.sample(10)
# Out:
# 2022-07-06 14:02:19,781 get_attendance_sport_id sport_id=11 season=2022;  returning 1187 games
# 2022-07-06 14:02:22,688 get_attendance_sport_id sport_id=12 season=2022;  returning 1133 games
# 2022-07-06 14:02:23,271 get_attendance_sport_id sport_id=13 season=2022;  returning 1142 games
# 2022-07-06 14:02:24,639 get_attendance_sport_id sport_id=14 season=2022;  returning 1146 games
# 2022-07-06 14:02:29,062 get_attendance_sport_id sport_id=23 season=2022;  returning 875 games
# 2022-07-06 14:02:29,070 get_attendance_all_levels season=2022;  returning 5483 games
#                                    link gameType season              gameDate  \
# gamePk
# 672176  /api/v1.1/game/672176/feed/live        R   2022  2022-06-12T23:05:00Z
# 670106  /api/v1.1/game/670106/feed/live        R   2022  2022-07-02T22:10:00Z
# 674804  /api/v1.1/game/674804/feed/live        R   2022  2022-06-23T23:35:00Z
# 665661  /api/v1.1/game/665661/feed/live        R   2022  2022-04-20T23:05:00Z
# ...
