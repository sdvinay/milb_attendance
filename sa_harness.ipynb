# %%
import pandas as pd
import numpy as np
import plotly.express as px

import scrape_attendance as sa

# %%
att = sa.get_attendance_all_levels(2022)
att.sample(10)
# Out:
# 2022-09-07 16:42:32,130 get_attendance_sport_id sport_id=11 season=2022;  returning 1954 games
# 2022-09-07 16:42:33,274 get_attendance_sport_id sport_id=12 season=2022;  returning 1892 games
# 2022-09-07 16:42:34,287 get_attendance_sport_id sport_id=13 season=2022;  returning 1913 games
# 2022-09-07 16:42:37,212 get_attendance_sport_id sport_id=14 season=2022;  returning 1924 games
# 2022-09-07 16:42:38,123 get_attendance_sport_id sport_id=23 season=2022;  returning 1458 games
# 2022-09-07 16:42:38,138 get_attendance_all_levels season=2022;  returning 9141 games
#                                    link gameType season              gameDate  \
# gamePk
# 673837  /api/v1.1/game/673837/feed/live        R   2022  2022-07-22T23:05:00Z
# 674018  /api/v1.1/game/674018/feed/live        R   2022  2022-04-16T23:35:00Z
# 664660  /api/v1.1/game/664660/feed/live        R   2022  2022-07-15T00:05:00Z
# 665623  /api/v1.1/game/665623/feed/live        R   2022  2022-04-19T22:05:00Z
# 664865  /api/v1.1/game/664865/feed/live        R   2022  2022-08-13T00:35:00Z
# 672563  /api/v1.1/game/672563/feed/live        R   2022  2022-05-20T23:05:00Z
# 664872  /api/v1.1/game/664872/feed/live        R   2022  2022-08-03T00:35:00Z
# 671170  /api/v1.1/game/671170/feed/live        R   2022  2022-06-04T23:05:00Z
# 674310  /api/v1.1/game/674310/feed/live        R   2022  2022-05-29T18:05:00Z
# 670081  /api/v1.1/game/670081/feed/live        R   2022  2022-04-20T23:05:00Z
#
#        officialDate  isTie  gameNumber  publicFacing doubleHeader gamedayType  \
# gamePk
# 673837   2022-07-22  False           1          True            N           Y
# 674018   2022-04-16  False           1          True            N           Y
# 664660   2022-07-14  False           1          True            N           E
# 665623   2022-04-19  False           1          True            N           Y
# 664865   2022-08-12  False           1          True            N           E
# 672563   2022-05-20  False           1          True            N           Y
# 664872   2022-08-02  False           1          True            N           E
# 671170   2022-06-04  False           1          True            N           Y
# 674310   2022-05-29  False           1          True            N           Y
# 670081   2022-04-20  False           1          True            N           Y
#
#         ... rescheduleDate rescheduleGameDate status.reason rescheduledFrom  \
# gamePk  ...
# 673837  ...            NaN                NaN           NaN             NaN
# 674018  ...            NaN                NaN           NaN             NaN
# 664660  ...            NaN                NaN           NaN             NaN
# 665623  ...            NaN                NaN           NaN             NaN
# 664865  ...            NaN                NaN           NaN             NaN
# 672563  ...            NaN                NaN           NaN             NaN
# 664872  ...            NaN                NaN           NaN             NaN
# 671170  ...            NaN                NaN           NaN             NaN
# 674310  ...            NaN                NaN           NaN             NaN
# 670081  ...            NaN                NaN           NaN             NaN
#
#         rescheduledFromDate  description  resumeDate  resumeGameDate  \
# gamePk
# 673837                  NaN          NaN         NaN             NaN
# 674018                  NaN          NaN         NaN             NaN
# 664660                  NaN          NaN         NaN             NaN
# 665623                  NaN          NaN         NaN             NaN
# 664865                  NaN          NaN         NaN             NaN
# 672563                  NaN          NaN         NaN             NaN
# 664872                  NaN          NaN         NaN             NaN
# 671170                  NaN          NaN         NaN             NaN
# 674310                  NaN          NaN         NaN             NaN
# 670081                  NaN          NaN         NaN             NaN
#
#         resumedFrom resumedFromDate
# gamePk
# 673837          NaN             NaN
# 674018          NaN             NaN
# 664660          NaN             NaN
# 665623          NaN             NaN
# 664865          NaN             NaN
# 672563          NaN             NaN
# 664872          NaN             NaN
# 671170          NaN             NaN
# 674310          NaN             NaN
# 670081          NaN             NaN
#
# [10 rows x 67 columns]

# %%
sa.main()
# Out:
# 2022-09-07 16:45:29,338 get_attendance_sport_id sport_id=11 season=2022;  returning 1954 games
# 2022-09-07 16:45:29,930 get_attendance_sport_id sport_id=12 season=2022;  returning 1892 games
# 2022-09-07 16:45:30,516 get_attendance_sport_id sport_id=13 season=2022;  returning 1913 games
# 2022-09-07 16:45:31,170 get_attendance_sport_id sport_id=14 season=2022;  returning 1924 games
# 2022-09-07 16:45:31,921 get_attendance_sport_id sport_id=23 season=2022;  returning 1458 games
# 2022-09-07 16:45:31,937 get_attendance_all_levels season=2022;  returning 9141 games
# 2022-09-07 16:45:31,979 generate_gbg_report returning report 9140 games
# 2022-09-07 16:45:31,979 Writing report(s) to ./output/attendance_2022.txt
# 2022-09-07 16:45:32,487 generate_summary_report returning report 148 teams
# 2022-09-07 16:45:32,488 Writing report(s) to ./output/attendance_summary_2022.txt

# %%
sa.generate_team_map()
# Out:
# 2022-09-07 16:42:38,644 generate_team_map season=2022 reporting 685 teams
#                              name           league.name  league.id  sport.id  \
# id
# 100   Georgia Tech Yellow Jackets      College Baseball      107.0        22
# 101       Florida State Seminoles      College Baseball      107.0        22
# 102            Round Rock Express  Pacific Coast League      112.0        11
# 103           Lake Elsinore Storm     California League      110.0        14
# 105         Sacramento River Cats  Pacific Coast League      112.0        11
# ...                           ...                   ...        ...       ...
# 6041    Wake Forest Demon Deacons      College Baseball      107.0        22
# 6042               Clemson Tigers      College Baseball      107.0        22
# 6043             Duke Blue Devils      College Baseball      107.0        22
# 6045                      Curacao      Caribbean Series      162.0        17
# 6046     International Team (18U)                   NaN        NaN       509
#
#      abbreviation  sortOrder
# id
# 100       College       5101
# 101       College       5101
# 102           AAA        101
# 103             A        401
# 105           AAA        101
# ...           ...        ...
# 6041      College       5101
# 6042      College       5101
# 6043      College       5101
# 6045          WIN       1301
# 6046          18U       3503
#
# [685 rows x 6 columns]

# %%
sa.generate_team_map(2019)
# Out:
# 2022-09-07 16:42:39,161 generate_team_map season=2019 reporting 592 teams
#                              name                 league.name  league.id  \
# id
# 100   Georgia Tech Yellow Jackets            College Baseball      107.0
# 101       Florida State Seminoles            College Baseball      107.0
# 102            Round Rock Express        Pacific Coast League      112.0
# 103           Lake Elsinore Storm           California League      110.0
# 104              Jackson Generals             Southern League      111.0
# ...                           ...                         ...        ...
# 5483        Sultanes de Monterrey  Liga Mexicana del Pacifico      132.0
# 5484             Mayos de Navojoa         Arizona Fall League      119.0
# 5492                     Colombia            Caribbean Series      162.0
# 5535               Tren del Norte                         NaN        NaN
# 6034    Notre Dame Fighting Irish            College Baseball      107.0
#
#       sport.id abbreviation  sortOrder
# id
# 100         22      College       5101
# 101         22      College       5101
# 102         11          AAA        101
# 103         13       A(Adv)        301
# 104         12           AA        201
# ...        ...          ...        ...
# 5483        17          WIN       1301
# 5484        17          WIN       1301
# 5492        17          WIN       1301
# 5535        17          WIN       1301
# 6034        22      College       5101
#
# [592 rows x 6 columns]

# %%
gbg = sa.generate_gbg_report(att)
gbg
# Out:
# 2022-09-07 16:42:39,284 generate_gbg_report returning report 9140 games
#        officialDate       teams.home.team.name abbreviation  \
# gamePk
# 665271   2022-09-07      Oklahoma City Dodgers          AAA
# 664961   2022-09-07         Round Rock Express          AAA
# 672885   2022-09-07        Hartford Yard Goats           AA
# 673061   2022-09-07         Winston-Salem Dash           A+
# 673481   2022-09-07     Jersey Shore BlueClaws           A+
# ...             ...                        ...          ...
# 666070   2022-04-05       Indianapolis Indians          AAA
# 665849   2022-04-05  Jacksonville Jumbo Shrimp          AAA
# 665715   2022-04-05     Lehigh Valley IronPigs          AAA
# 665487   2022-04-05           Nashville Sounds          AAA
# 665604   2022-04-05           Memphis Redbirds          AAA
#
#                   league.name  gameInfo.attendance dayNight  dayOfWeek  \
# gamePk
# 665271   Pacific Coast League                 3084      day  Wednesday
# 664961   Pacific Coast League                 3029      day  Wednesday
# 672885         Eastern League                    0    night  Wednesday
# 673061  South Atlantic League                 2118      day  Wednesday
# 673481  South Atlantic League                    0    night  Wednesday
# ...                       ...                  ...      ...        ...
# 666070   International League                 7724    night    Tuesday
# 665849   International League                 5907    night    Tuesday
# 665715   International League                 7085    night    Tuesday
# 665487   International League                 6136    night    Tuesday
# 665604   International League                 2246    night    Tuesday
#
#             teams.away.team.name  gameInfo.gameDurationMinutes
# gamePk
# 665271           Tacoma Rainiers                         165.0
# 664961  Sugar Land Space Cowboys                         181.0
# 672885         Somerset Patriots                         105.0
# 673061         Brooklyn Cyclones                         149.0
# 673481        Aberdeen IronBirds                          99.0
# ...                          ...                           ...
# 666070       Omaha Storm Chasers                         185.0
# 665849         Worcester Red Sox                         179.0
# 665715         Columbus Clippers                         203.0
# 665487              Durham Bulls                         215.0
# 665604         Gwinnett Stripers                         162.0
#
# [9140 rows x 9 columns]

# %%
sa.generate_summary_report(att)
# Out:
# 2022-09-07 16:42:39,334 generate_summary_report returning report 148 teams
#               teams.home.team.name abbreviation           league.name  \
# 342           Albuquerque Isotopes          AAA  Pacific Coast League
# 400             Las Vegas Aviators          AAA  Pacific Coast League
# 4904            El Paso Chihuahuas          AAA  Pacific Coast League
# 561                 Salt Lake Bees          AAA  Pacific Coast League
# 238          Oklahoma City Dodgers          AAA  Pacific Coast League
# ...                            ...          ...                   ...
# 5431            High Point Rockers          IND       Atlantic League
# 525         Charleston Dirty Birds          IND       Atlantic League
# 6015  Kentucky Wild Health Genomes          IND       Atlantic League
# 5508        Gastonia Honey Hunters          IND       Atlantic League
# 586      Staten Island Ferry Hawks          IND       Atlantic League
#
#       num_games  total_att  avg_att  median_duration
# 342          62     441856     7126              161
# 400          63     433049     6873              170
# 4904         64     433756     6777              172
# 561          64     369507     5773              159
# 238          68     370155     5443              173
# ...         ...        ...      ...              ...
# 5431         61     113920     1867              173
# 525          58     104042     1793              180
# 6015         57      90815     1593              184
# 5508         64      99944     1561              194
# 586          58      65396     1127              172
#
# [148 rows x 7 columns]

# %%
att19 = sa.get_attendance_all_levels(2019)
att19.sample(10)
# Out:
# 2022-09-07 16:42:40,194 get_attendance_sport_id sport_id=11 season=2019;  returning 3137 games
# 2022-09-07 16:42:40,760 get_attendance_sport_id sport_id=12 season=2019;  returning 2142 games
# 2022-09-07 16:42:41,423 get_attendance_sport_id sport_id=13 season=2019;  returning 2097 games
# 2022-09-07 16:42:42,112 get_attendance_sport_id sport_id=14 season=2019;  returning 2126 games
# 2022-09-07 16:42:42,362 get_attendance_sport_id sport_id=23 season=2019;  returning 560 games
# 2022-09-07 16:42:42,377 get_attendance_all_levels season=2019;  returning 10062 games
#                                    link gameType season              gameDate  \
# gamePk
# 584663  /api/v1.1/game/584663/feed/live        R   2019  2019-06-30T23:10:00Z
# 573042  /api/v1.1/game/573042/feed/live        R   2019  2019-08-11T17:00:00Z
# 571940  /api/v1.1/game/571940/feed/live        R   2019  2019-05-11T22:05:00Z
# 588477  /api/v1.1/game/588477/feed/live        R   2019  2019-07-01T22:35:00Z
# 574519  /api/v1.1/game/574519/feed/live        R   2019  2019-06-12T23:05:00Z
# 601409  /api/v1.1/game/601409/feed/live        W   2019  2019-09-11T22:35:00Z
# 574251  /api/v1.1/game/574251/feed/live        R   2019  2019-07-09T23:05:00Z
# 574561  /api/v1.1/game/574561/feed/live        R   2019  2019-04-07T19:05:00Z
# 577704  /api/v1.1/game/577704/feed/live        R   2019  2019-06-27T23:05:00Z
# 572221  /api/v1.1/game/572221/feed/live        R   2019  2019-05-03T23:05:00Z
#
#        officialDate  isTie  gameNumber  publicFacing doubleHeader gamedayType  \
# gamePk
# 584663   2019-06-30  False           1          True            N           Y
# 573042   2019-08-11  False           1          True            N           Y
# 571940   2019-05-11  False           1          True            N           Y
# 588477   2019-07-01  False           1          True            N           P
# 574519   2019-06-12  False           1          True            N           Y
# 601409   2019-09-11  False           1          True            N           Y
# 574251   2019-07-09  False           1          True            N           Y
# 574561   2019-04-06  False           1          True            N           Y
# 577704   2019-06-27  False           1          True            N           Y
# 572221   2019-05-03  False           1          True            N           Y
#
#         ...              description rescheduleDate rescheduleGameDate  \
# gamePk  ...
# 584663  ...                      NaN            NaN                NaN
# 573042  ...                      NaN            NaN                NaN
# 571940  ...                      NaN            NaN                NaN
# 588477  ...                      NaN            NaN                NaN
# 574519  ...                      NaN            NaN                NaN
# 601409  ...  INT Championship Game 2            NaN                NaN
# 574251  ...                      NaN            NaN                NaN
# 574561  ...                      NaN            NaN                NaN
# 577704  ...                      NaN            NaN                NaN
# 572221  ...                      NaN            NaN                NaN
#
#        status.reason  rescheduledFrom  rescheduledFromDate  resumeDate  \
# gamePk
# 584663           NaN              NaN                  NaN         NaN
# 573042           NaN              NaN                  NaN         NaN
# 571940           NaN              NaN                  NaN         NaN
# 588477           NaN              NaN                  NaN         NaN
# 574519           NaN              NaN                  NaN         NaN
# 601409           NaN              NaN                  NaN         NaN
# 574251           NaN              NaN                  NaN         NaN
# 574561           NaN              NaN                  NaN         NaN
# 577704           NaN              NaN                  NaN         NaN
# 572221           NaN              NaN                  NaN         NaN
#
#         resumeGameDate           resumedFrom resumedFromDate
# gamePk
# 584663             NaN                   NaN             NaN
# 573042             NaN                   NaN             NaN
# 571940             NaN                   NaN             NaN
# 588477             NaN                   NaN             NaN
# 574519             NaN                   NaN             NaN
# 601409             NaN                   NaN             NaN
# 574251             NaN                   NaN             NaN
# 574561             NaN  2019-04-06T22:35:00Z      2019-04-06
# 577704             NaN                   NaN             NaN
# 572221             NaN                   NaN             NaN
#
# [10 rows x 67 columns]

# %%
att19['gameInfo.gameDurationMinutes'].min()
# Out:
# 40.0

# %%
att19[att19['gameInfo.gameDurationMinutes']<100]
# Out:
#                                    link gameType season              gameDate  \
# gamePk
# 575721  /api/v1.1/game/575721/feed/live        R   2019  2019-04-12T22:35:00Z
# 575234  /api/v1.1/game/575234/feed/live        R   2019  2019-04-24T23:00:00Z
# 575166  /api/v1.1/game/575166/feed/live        R   2019  2019-05-04T22:35:00Z
# 579558  /api/v1.1/game/579558/feed/live        R   2019  2019-05-16T21:43:00Z
# 575671  /api/v1.1/game/575671/feed/live        R   2019  2019-06-02T17:10:00Z
# 575512  /api/v1.1/game/575512/feed/live        R   2019  2019-07-05T22:10:00Z
# 574282  /api/v1.1/game/574282/feed/live        R   2019  2019-04-07T19:35:00Z
# 572278  /api/v1.1/game/572278/feed/live        R   2019  2019-04-13T17:00:00Z
# 571513  /api/v1.1/game/571513/feed/live        R   2019  2019-04-20T17:10:00Z
# 572083  /api/v1.1/game/572083/feed/live        R   2019  2019-05-05T17:00:00Z
# 574439  /api/v1.1/game/574439/feed/live        R   2019  2019-05-11T23:15:00Z
# 574719  /api/v1.1/game/574719/feed/live        R   2019  2019-05-12T00:05:00Z
# 574868  /api/v1.1/game/574868/feed/live        R   2019  2019-06-06T21:00:00Z
# 571681  /api/v1.1/game/571681/feed/live        R   2019  2019-06-24T21:35:00Z
# 574666  /api/v1.1/game/574666/feed/live        R   2019  2019-06-27T22:35:00Z
# 572076  /api/v1.1/game/572076/feed/live        R   2019  2019-07-02T21:05:00Z
# 571760  /api/v1.1/game/571760/feed/live        R   2019  2019-07-06T22:35:00Z
# 574530  /api/v1.1/game/574530/feed/live        R   2019  2019-07-13T23:05:00Z
# 574535  /api/v1.1/game/574535/feed/live        R   2019  2019-07-23T22:05:00Z
# 572333  /api/v1.1/game/572333/feed/live        R   2019  2019-08-01T21:00:00Z
# 571701  /api/v1.1/game/571701/feed/live        R   2019  2019-08-13T21:35:00Z
# 574690  /api/v1.1/game/574690/feed/live        R   2019  2019-08-19T22:05:00Z
# 572710  /api/v1.1/game/572710/feed/live        R   2019  2019-05-01T22:00:00Z
# 572781  /api/v1.1/game/572781/feed/live        R   2019  2019-05-02T20:05:00Z
# 572714  /api/v1.1/game/572714/feed/live        R   2019  2019-05-05T16:00:00Z
# 573019  /api/v1.1/game/573019/feed/live        R   2019  2019-06-30T17:00:00Z
# 573162  /api/v1.1/game/573162/feed/live        R   2019  2019-07-07T16:05:00Z
# 572953  /api/v1.1/game/572953/feed/live        R   2019  2019-07-09T21:00:00Z
# 573019  /api/v1.1/game/573019/feed/live        R   2019  2019-08-02T21:30:00Z
# 572962  /api/v1.1/game/572962/feed/live        R   2019  2019-08-02T22:30:00Z
# 572894  /api/v1.1/game/572894/feed/live        R   2019  2019-08-03T19:00:00Z
# 573036  /api/v1.1/game/573036/feed/live        R   2019  2019-08-07T20:05:00Z
# 572550  /api/v1.1/game/572550/feed/live        R   2019  2019-08-17T20:05:00Z
# 572971  /api/v1.1/game/572971/feed/live        R   2019  2019-08-20T21:00:00Z
# 572692  /api/v1.1/game/572692/feed/live        R   2019  2019-08-28T21:00:00Z
# 577067  /api/v1.1/game/577067/feed/live        R   2019  2019-06-09T17:05:00Z
# 577840  /api/v1.1/game/577840/feed/live        R   2019  2019-06-15T23:35:00Z
# 577777  /api/v1.1/game/577777/feed/live        R   2019  2019-06-30T23:35:00Z
# 574136  /api/v1.1/game/574136/feed/live        R   2019  2019-08-28T16:10:00Z
#
#        officialDate  isTie  gameNumber  publicFacing doubleHeader gamedayType  \
# gamePk
# 575721   2019-04-12  False           1          True            N           Y
# 575234   2019-04-24  False           1          True            N           Y
# 575166   2019-05-04  False           1          True            N           Y
# 579558   2019-05-16  False           2          True            Y           Y
# 575671   2019-06-02  False           2          True            Y           Y
# 575512   2019-07-05  False           2          True            Y           Y
# 574282   2019-04-07  False           1          True            N           Y
# 572278   2019-04-13  False           1          True            N           Y
# 571513   2019-04-20  False           2          True            Y           Y
# 572083   2019-05-05  False           1          True            Y           Y
# 574439   2019-05-11  False           1          True            N           Y
# 574719   2019-05-11  False           1          True            N           Y
# 574868   2019-06-06  False           1          True            Y           Y
# 571681   2019-06-24  False           1          True            N           Y
# 574666   2019-06-27  False           1          True            Y           Y
# 572076   2019-07-02  False           2          True            Y           Y
# 571760   2019-07-06  False           1          True            N           Y
# 574530   2019-07-13  False           1          True            N           Y
# 574535   2019-07-23  False           1          True            Y           Y
# 572333   2019-08-01  False           1          True            Y           Y
# 571701   2019-08-13  False           1          True            Y           Y
# 574690   2019-08-19  False           1          True            Y           Y
# 572710   2019-05-01  False           1          True            N           Y
# 572781   2019-05-02  False           2          True            Y           Y
# 572714   2019-05-05  False           1          True            N           Y
# 573019   2019-06-30  False           1          True            N           Y
# 573162   2019-07-07  False           2          True            Y           Y
# 572953   2019-07-09  False           1          True            Y           Y
# 573019   2019-06-30  False           1          True            N           Y
# 572962   2019-08-02  False           1          True            N           Y
# 572894   2019-08-03  False           1          True            Y           Y
# 573036   2019-08-07  False           2          True            Y           Y
# 572550   2019-08-17  False           2          True            Y           Y
# 572971   2019-08-20  False           1          True            Y           Y
# 572692   2019-08-28  False           1          True            Y           Y
# 577067   2019-06-09  False           1          True            Y           Y
# 577840   2019-06-15  False           1          True            N           Y
# 577777   2019-06-30  False           1          True            N           Y
# 574136   2019-08-28  False           2          True            Y           Y
#
#         ...                                      description rescheduleDate  \
# gamePk  ...
# 575721  ...                                              NaN            NaN
# 575234  ...                                              NaN            NaN
# 575166  ...                                              NaN            NaN
# 579558  ...                               Makeup of 4/10 PPD            NaN
# 575671  ...                                Makeup of 6/1 ppd            NaN
# 575512  ...                               Makeup of 4/18 PPD            NaN
# 574282  ...                                              NaN            NaN
# 572278  ...                                              NaN            NaN
# 571513  ...                               Makeup of 4/19 PPD            NaN
# 572083  ...                                              NaN            NaN
# 574439  ...                                              NaN            NaN
# 574719  ...                                              NaN            NaN
# 574868  ...                                              NaN            NaN
# 571681  ...                                              NaN            NaN
# 574666  ...                                              NaN            NaN
# 572076  ...                                  Makeup 4/20 ppd            NaN
# 571760  ...                                              NaN            NaN
# 574530  ...                                              NaN            NaN
# 574535  ...                                              NaN            NaN
# 572333  ...                                              NaN            NaN
# 571701  ...                                              NaN            NaN
# 574690  ...                                              NaN            NaN
# 572710  ...                                              NaN            NaN
# 572781  ...                                     PPD FROM 5/1            NaN
# 572714  ...                                              NaN            NaN
# 573019  ...                                              NaN            NaN
# 573162  ...                         Makeup of 7/6 PPD (Rain)            NaN
# 572953  ...                                              NaN            NaN
# 573019  ...                                              NaN            NaN
# 572962  ...                                              NaN            NaN
# 572894  ...                                              NaN            NaN
# 573036  ...  Palm Beach home game - Makeup of 8/5 PPD (Rain)            NaN
# 572550  ...                        Makeup of 8/16 PPD (Rain)            NaN
# 572971  ...                                              NaN            NaN
# 572692  ...                                              NaN            NaN
# 577067  ...                                              NaN            NaN
# 577840  ...                                              NaN            NaN
# 577777  ...                                              NaN            NaN
# 574136  ...                        Makeup of 8/27 PPD (Rain)            NaN
#
#        rescheduleGameDate      status.reason       rescheduledFrom  \
# gamePk
# 575721                NaN               Rain                   NaN
# 575234                NaN               Rain                   NaN
# 575166                NaN               Rain                   NaN
# 579558                NaN               Rain  2019-04-10T23:38:00Z
# 575671                NaN                NaN  2019-06-01T23:05:00Z
# 575512                NaN                NaN  2019-04-18T23:05:00Z
# 574282                NaN                NaN                   NaN
# 572278                NaN                NaN                   NaN
# 571513                NaN                NaN  2019-04-19T22:35:00Z
# 572083                NaN                NaN                   NaN
# 574439                NaN               Rain                   NaN
# 574719                NaN               Rain                   NaN
# 574868                NaN                NaN                   NaN
# 571681                NaN                NaN                   NaN
# 574666                NaN                NaN                   NaN
# 572076                NaN                NaN  2019-04-20T17:00:00Z
# 571760                NaN               Rain                   NaN
# 574530                NaN               Rain                   NaN
# 574535                NaN                NaN                   NaN
# 572333                NaN                NaN                   NaN
# 571701                NaN                NaN                   NaN
# 574690                NaN                NaN                   NaN
# 572710                NaN                NaN                   NaN
# 572781                NaN                NaN  2019-05-01T17:00:00Z
# 572714                NaN        Wet Grounds                   NaN
# 573019                NaN                NaN                   NaN
# 573162                NaN                NaN  2019-07-06T22:30:00Z
# 572953                NaN                NaN                   NaN
# 573019                NaN                NaN                   NaN
# 572962                NaN               Rain                   NaN
# 572894                NaN                NaN                   NaN
# 573036                NaN                NaN  2019-08-05T22:30:00Z
# 572550                NaN                NaN  2019-08-16T22:30:00Z
# 572971                NaN                NaN                   NaN
# 572692                NaN                NaN                   NaN
# 577067                NaN                NaN                   NaN
# 577840                NaN               Rain                   NaN
# 577777                NaN  Inclement Weather                   NaN
# 574136                NaN                NaN  2019-08-27T23:05:00Z
#
#         rescheduledFromDate            resumeDate  resumeGameDate  \
# gamePk
# 575721                  NaN                   NaN             NaN
# 575234                  NaN                   NaN             NaN
# 575166                  NaN                   NaN             NaN
# 579558           2019-04-10                   NaN             NaN
# 575671           2019-06-01                   NaN             NaN
# 575512           2019-04-18                   NaN             NaN
# 574282                  NaN                   NaN             NaN
# 572278                  NaN                   NaN             NaN
# 571513           2019-04-19                   NaN             NaN
# 572083                  NaN                   NaN             NaN
# 574439                  NaN                   NaN             NaN
# 574719                  NaN                   NaN             NaN
# 574868                  NaN                   NaN             NaN
# 571681                  NaN                   NaN             NaN
# 574666                  NaN                   NaN             NaN
# 572076           2019-04-20                   NaN             NaN
# 571760                  NaN                   NaN             NaN
# 574530                  NaN                   NaN             NaN
# 574535                  NaN                   NaN             NaN
# 572333                  NaN                   NaN             NaN
# 571701                  NaN                   NaN             NaN
# 574690                  NaN                   NaN             NaN
# 572710                  NaN                   NaN             NaN
# 572781           2019-05-01                   NaN             NaN
# 572714                  NaN                   NaN             NaN
# 573019                  NaN  2019-08-02T21:30:00Z      2019-08-02
# 573162           2019-07-06                   NaN             NaN
# 572953                  NaN                   NaN             NaN
# 573019                  NaN                   NaN             NaN
# 572962                  NaN                   NaN             NaN
# 572894                  NaN                   NaN             NaN
# 573036           2019-08-05                   NaN             NaN
# 572550           2019-08-16                   NaN             NaN
# 572971                  NaN                   NaN             NaN
# 572692                  NaN                   NaN             NaN
# 577067                  NaN                   NaN             NaN
# 577840                  NaN                   NaN             NaN
# 577777                  NaN                   NaN             NaN
# 574136           2019-08-27                   NaN             NaN
#
#                  resumedFrom resumedFromDate
# gamePk
# 575721                   NaN             NaN
# 575234                   NaN             NaN
# 575166                   NaN             NaN
# 579558                   NaN             NaN
# 575671                   NaN             NaN
# 575512                   NaN             NaN
# 574282                   NaN             NaN
# 572278                   NaN             NaN
# 571513                   NaN             NaN
# 572083                   NaN             NaN
# 574439                   NaN             NaN
# 574719                   NaN             NaN
# 574868                   NaN             NaN
# 571681                   NaN             NaN
# 574666                   NaN             NaN
# 572076                   NaN             NaN
# 571760                   NaN             NaN
# 574530                   NaN             NaN
# 574535                   NaN             NaN
# 572333                   NaN             NaN
# 571701                   NaN             NaN
# 574690                   NaN             NaN
# 572710                   NaN             NaN
# 572781                   NaN             NaN
# 572714                   NaN             NaN
# 573019                   NaN             NaN
# 573162                   NaN             NaN
# 572953                   NaN             NaN
# 573019  2019-06-30T17:00:00Z      2019-06-30
# 572962                   NaN             NaN
# 572894                   NaN             NaN
# 573036                   NaN             NaN
# 572550                   NaN             NaN
# 572971                   NaN             NaN
# 572692                   NaN             NaN
# 577067                   NaN             NaN
# 577840                   NaN             NaN
# 577777                   NaN             NaN
# 574136                   NaN             NaN
#
# [39 rows x 67 columns]

# %%
# WTF are the Minnesota Twins doing in this data?
att19[att19['teams.home.team.id']==142].T
# Out:
# gamePk                                        568145
# link                 /api/v1.1/game/568145/feed/live
# gameType                                           E
# season                                          2019
# gameDate                        2019-03-25T17:05:00Z
# officialDate                              2019-03-25
# ...                                              ...
# rescheduledFromDate                              NaN
# resumeDate                                       NaN
# resumeGameDate                                   NaN
# resumedFrom                                      NaN
# resumedFromDate                                  NaN
#
# [67 rows x 1 columns]

# %%
sa.generate_summary_report(att19)
# Out:
# 2022-09-07 16:42:42,584 generate_summary_report returning report 133 teams
#        teams.home.team.name abbreviation           league.name  num_games  \
# 400      Las Vegas Aviators          AAA  Pacific Coast League         70
# 102      Round Rock Express          AAA  Pacific Coast League         70
# 105   Sacramento River Cats          AAA  Pacific Coast League         70
# 342    Albuquerque Isotopes          AAA  Pacific Coast League         71
# 4904     El Paso Chihuahuas          AAA  Pacific Coast League         70
# ...                     ...          ...                   ...        ...
# 5435        York Revolution          IND       Atlantic League         70
# 5431     High Point Rockers          IND       Atlantic League         70
# 525     West Virginia Power          IND       Atlantic League         70
# 567         Trenton Thunder      College      MLB Draft League         72
# 493          Frederick Keys      College      MLB Draft League         71
#
#       total_att  avg_att  median_duration
# 400      650934     9299              186
# 102      597928     8541              187
# 105      549440     7849              183
# 342      550868     7758              183
# 4904     522895     7469              187
# ...         ...      ...              ...
# 5435     199047     2843              179
# 5431     144487     2064              160
# 525      118446     1692              162
# 567      357041     4958              157
# 493      266386     3751              169
#
# [133 rows x 7 columns]

# %%
att19['gameType'].value_counts()
# Out:
# R    9885
# L      80
# W      43
# D      35
# A      11
# E       7
# C       1
# Name: gameType, dtype: int64

# %%
att.columns
# Out:
# Index(['link', 'gameType', 'season', 'gameDate', 'officialDate', 'isTie',
#        'gameNumber', 'publicFacing', 'doubleHeader', 'gamedayType',
#        'tiebreaker', 'calendarEventID', 'seasonDisplay', 'dayNight',
#        'scheduledInnings', 'reverseHomeAwayStatus', 'inningBreakLength',
#        'gamesInSeries', 'seriesGameNumber', 'seriesDescription',
#        'recordSource', 'ifNecessary', 'ifNecessaryDescription',
#        'status.abstractGameState', 'status.codedGameState',
#        'status.detailedState', 'status.statusCode', 'status.startTimeTBD',
#        'status.abstractGameCode', 'teams.away.leagueRecord.wins',
#        'teams.away.leagueRecord.losses', 'teams.away.leagueRecord.pct',
#        'teams.away.score', 'teams.away.team.id', 'teams.away.team.name',
#        'teams.away.team.link', 'teams.away.isWinner', 'teams.away.splitSquad',
#        'teams.away.seriesNumber', 'teams.home.leagueRecord.wins',
#        'teams.home.leagueRecord.losses', 'teams.home.leagueRecord.pct',
#        'teams.home.score', 'teams.home.team.id', 'teams.home.team.name',
#        'teams.home.team.link', 'teams.home.isWinner', 'teams.home.splitSquad',
#        'teams.home.seriesNumber', 'venue.id', 'venue.name', 'venue.link',
#        'content.link', 'gameInfo.attendance', 'gameInfo.firstPitch',
#        'gameInfo.gameDurationMinutes', 'gameInfo.delayDurationMinutes',
#        'rescheduleDate', 'rescheduleGameDate', 'status.reason',
#        'rescheduledFrom', 'rescheduledFromDate', 'description', 'resumeDate',
#        'resumeGameDate', 'resumedFrom', 'resumedFromDate', 'dayOfWeek'],
#       dtype='object')

# %%
gbg['month'] = pd.to_datetime(gbg['officialDate']).dt.month
gbg['month'].sample(10)
# Out:
# gamePk
# 669389    4
# 674471    7
# 670109    6
# 664770    4
# 705921    4
# 674018    4
# 672980    8
# 673677    5
# 669273    6
# 671935    7
# Name: month, dtype: int64

# %%
print(gbg.groupby(['league.name', 'month'])['gameInfo.gameDurationMinutes'].agg([np.mean, np.median, len]).to_string())
# Out:
#                                    mean  median  len
# league.name           month
# Atlantic League       4      191.046512   192.0   43
#                       5      176.906977   175.0  129
#                       6      184.192593   185.0  135
#                       7      187.878571   185.0  140
#                       8      190.969925   191.0  133
#                       9      189.846154   188.0   26
# California League     4      166.512500   161.0   80
#                       5      157.211538   153.5  104
#                       6      160.000000   157.0  105
#                       7      160.947917   160.0   96
#                       8      168.346154   166.0  104
#                       9      166.142857   166.0   21
# Carolina League       4      164.426230   162.0  122
#                       5      151.993631   151.0  157
#                       6      149.440252   148.0  159
#                       7      153.406897   154.0  145
#                       8      155.685535   152.0  159
#                       9      163.066667   161.0   30
# Eastern League        4      157.857143   160.0  119
#                       5      151.129870   151.0  154
#                       6      151.672956   152.0  159
#                       7      161.121429   159.0  140
#                       8      158.569620   157.5  158
#                       9      158.448276   155.0   29
# Florida State League  4      158.729167   157.0   96
#                       5      144.889706   145.0  136
#                       6      146.539062   146.5  128
#                       7      143.918699   143.0  123
#                       8      151.240602   152.0  133
#                       9      146.230769   147.5   26
# International League  4      163.714912   162.0  228
#                       5      155.747126   154.0  261
#                       6      159.811538   159.0  260
#                       7      160.769547   160.0  243
#                       8      161.934615   162.0  260
#                       9      157.780000   161.5   50
# Mexican League        4      200.422535   200.0   71
#                       5      196.923077   198.0  234
#                       6      192.965347   191.5  202
#                       7      188.068670   186.0  233
#                       8      202.103774   203.5  106
#                       9      248.400000   244.0    5
# Midwest League        4      149.974790   149.0  119
#                       5      145.310127   148.0  158
#                       6      154.949367   153.5  158
#                       7      154.338028   152.0  142
#                       8      154.592357   155.0  157
#                       9      152.625000   149.0   32
# Northwest League      4      153.017241   151.5   58
#                       5      141.216216   142.0   74
#                       6      147.283951   151.0   81
#                       7      153.154930   149.0   71
#                       8      148.375000   148.0   80
#                       9      151.933333   153.0   15
# Pacific Coast League  4      171.400000   169.0  115
#                       5      166.713178   164.0  129
#                       6      167.244275   166.0  131
#                       7      168.314050   167.0  121
#                       8      168.023077   169.0  130
#                       9      166.230769   161.5   26
# South Atlantic League 4      160.583333   158.5  120
#                       5      150.575163   152.0  153
#                       6      152.552795   150.0  161
#                       7      157.201389   156.0  144
#                       8      155.566038   153.0  159
#                       9      153.258065   152.0   31
# Southern League       4      163.275000   166.0   80
#                       5      158.173469   159.0   98
#                       6      160.048077   157.5  104
#                       7      162.686869   161.0   99
#                       8      161.203883   164.0  103
#                       9      159.777778   161.5   18
# Texas League          4      166.830000   163.5  100
#                       5      157.581395   160.0  129
#                       6      156.930769   154.0  130
#                       7      166.275000   162.0  120
#                       8      163.015625   161.0  128
#                       9      162.208333   167.0   24

# %%
for_graphing = gbg.groupby(['league.name', 'month'])['gameInfo.gameDurationMinutes'].agg([np.mean, np.median]).reset_index()
px.line(for_graphing, x='month', color='league.name', y=['median', 'mean'])

# %%
for_graphing
# Out:
#         league.name  month        mean  median
# 0   Atlantic League      4  191.046512   192.0
# 1   Atlantic League      5  176.906977   175.0
# 2   Atlantic League      6  184.192593   185.0
# 3   Atlantic League      7  187.878571   185.0
# 4   Atlantic League      8  190.969925   191.0
# ..              ...    ...         ...     ...
# 73     Texas League      5  157.581395   160.0
# 74     Texas League      6  156.930769   154.0
# 75     Texas League      7  166.275000   162.0
# 76     Texas League      8  163.015625   161.0
# 77     Texas League      9  162.208333   167.0
#
# [78 rows x 4 columns]
