# %%
import scrape_attendance as sa
import pandas as pd

# %%
#att = sa.get_attendance_all_levels(2022)
#att.sample(10)

# %%
sa.generate_team_map()
# Out:
# 2022-09-07 08:50:34,876 generate_team_map season=2022 reporting 685 teams
#                              name           league.name  league.id  sport.id  \
# id
# 100   Georgia Tech Yellow Jackets      College Baseball      107.0        22
# 101       Florida State Seminoles      College Baseball      107.0        22
# 102            Round Rock Express  Pacific Coast League      112.0        11
# 103           Lake Elsinore Storm     California League      110.0        14
# 105         Sacramento River Cats  Pacific Coast League      112.0        11
# ...                           ...                   ...        ...       ...
# 6041    Wake Forest Demon Deacons      College Baseball      107.0        22
# 6042               Clemson Tigers      College Baseball      107.0        22
# 6043             Duke Blue Devils      College Baseball      107.0        22
# 6045                      Curacao      Caribbean Series      162.0        17
# 6046     International Team (18U)                   NaN        NaN       509
#
#      abbreviation  sortOrder
# id
# 100       College       5101
# 101       College       5101
# 102           AAA        101
# 103             A        401
# 105           AAA        101
# ...           ...        ...
# 6041      College       5101
# 6042      College       5101
# 6043      College       5101
# 6045          WIN       1301
# 6046          18U       3503
#
# [685 rows x 6 columns]

# %%
sa.generate_team_map(2019)
# Out:
# 2022-09-07 08:50:35,398 generate_team_map season=2019 reporting 592 teams
#                              name                 league.name  league.id  \
# id
# 100   Georgia Tech Yellow Jackets            College Baseball      107.0
# 101       Florida State Seminoles            College Baseball      107.0
# 102            Round Rock Express        Pacific Coast League      112.0
# 103           Lake Elsinore Storm           California League      110.0
# 104              Jackson Generals             Southern League      111.0
# ...                           ...                         ...        ...
# 5483        Sultanes de Monterrey  Liga Mexicana del Pacifico      132.0
# 5484             Mayos de Navojoa         Arizona Fall League      119.0
# 5492                     Colombia            Caribbean Series      162.0
# 5535               Tren del Norte                         NaN        NaN
# 6034    Notre Dame Fighting Irish            College Baseball      107.0
#
#       sport.id abbreviation  sortOrder
# id
# 100         22      College       5101
# 101         22      College       5101
# 102         11          AAA        101
# 103         13       A(Adv)        301
# 104         12           AA        201
# ...        ...          ...        ...
# 5483        17          WIN       1301
# 5484        17          WIN       1301
# 5492        17          WIN       1301
# 5535        17          WIN       1301
# 6034        22      College       5101
#
# [592 rows x 6 columns]

# %%
att = sa.get_attendance_sport_id(11)
att
# Out:
# 2022-09-07 08:50:36,050 get_attendance_sport_id sport_id=11 season=2022;  returning 1952 games
#                                    link gameType season              gameDate  \
# gamePk
# 666415  /api/v1.1/game/666415/feed/live        R   2022  2022-04-05T17:05:00Z
# 664476  /api/v1.1/game/664476/feed/live        R   2022  2022-04-05T20:05:00Z
# 664589  /api/v1.1/game/664589/feed/live        R   2022  2022-04-05T22:35:00Z
# 665458  /api/v1.1/game/665458/feed/live        R   2022  2022-04-05T22:35:00Z
# 665576  /api/v1.1/game/665576/feed/live        R   2022  2022-04-05T22:35:00Z
# ...                                 ...      ...    ...                   ...
# 665524  /api/v1.1/game/665524/feed/live        R   2022  2022-09-06T23:45:00Z
# 665272  /api/v1.1/game/665272/feed/live        R   2022  2022-09-07T00:05:00Z
# 664850  /api/v1.1/game/664850/feed/live        R   2022  2022-09-07T00:35:00Z
# 666384  /api/v1.1/game/666384/feed/live        R   2022  2022-09-07T00:35:00Z
# 664989  /api/v1.1/game/664989/feed/live        R   2022  2022-09-07T01:35:00Z
#
#        officialDate  isTie  gameNumber  publicFacing doubleHeader gamedayType  \
# gamePk
# 666415   2022-04-05  False           1          True            N           Y
# 664476   2022-04-05  False           1          True            N           Y
# 664589   2022-04-05  False           1          True            N           Y
# 665458   2022-04-05  False           1          True            N           Y
# 665576   2022-04-05  False           1          True            N           Y
# ...             ...    ...         ...           ...          ...         ...
# 665524   2022-09-06  False           1          True            N           Y
# 665272   2022-09-06  False           1          True            N           E
# 664850   2022-09-06  False           1          True            N           E
# 666384   2022-09-06  False           1          True            N           E
# 664989   2022-09-06  False           1          True            N           E
#
#         ... rescheduleDate rescheduleGameDate status.reason rescheduledFrom  \
# gamePk  ...
# 666415  ...            NaN                NaN           NaN             NaN
# 664476  ...            NaN                NaN           NaN             NaN
# 664589  ...            NaN                NaN           NaN             NaN
# 665458  ...            NaN                NaN           NaN             NaN
# 665576  ...            NaN                NaN           NaN             NaN
# ...     ...            ...                ...           ...             ...
# 665524  ...            NaN                NaN           NaN             NaN
# 665272  ...            NaN                NaN           NaN             NaN
# 664850  ...            NaN                NaN           NaN             NaN
# 666384  ...            NaN                NaN           NaN             NaN
# 664989  ...            NaN                NaN           NaN             NaN
#
#         rescheduledFromDate  description  resumeDate  resumeGameDate  \
# gamePk
# 666415                  NaN          NaN         NaN             NaN
# 664476                  NaN          NaN         NaN             NaN
# 664589                  NaN          NaN         NaN             NaN
# 665458                  NaN          NaN         NaN             NaN
# 665576                  NaN          NaN         NaN             NaN
# ...                     ...          ...         ...             ...
# 665524                  NaN          NaN         NaN             NaN
# 665272                  NaN          NaN         NaN             NaN
# 664850                  NaN          NaN         NaN             NaN
# 666384                  NaN          NaN         NaN             NaN
# 664989                  NaN          NaN         NaN             NaN
#
#         resumedFrom resumedFromDate
# gamePk
# 666415          NaN             NaN
# 664476          NaN             NaN
# 664589          NaN             NaN
# 665458          NaN             NaN
# 665576          NaN             NaN
# ...             ...             ...
# 665524          NaN             NaN
# 665272          NaN             NaN
# 664850          NaN             NaN
# 666384          NaN             NaN
# 664989          NaN             NaN
#
# [1952 rows x 67 columns]

# %%
att.columns
# Out:
# Index(['link', 'gameType', 'season', 'gameDate', 'officialDate', 'isTie',
#        'gameNumber', 'publicFacing', 'doubleHeader', 'gamedayType',
#        'tiebreaker', 'calendarEventID', 'seasonDisplay', 'dayNight',
#        'scheduledInnings', 'reverseHomeAwayStatus', 'inningBreakLength',
#        'gamesInSeries', 'seriesGameNumber', 'seriesDescription',
#        'recordSource', 'ifNecessary', 'ifNecessaryDescription',
#        'status.abstractGameState', 'status.codedGameState',
#        'status.detailedState', 'status.statusCode', 'status.startTimeTBD',
#        'status.abstractGameCode', 'teams.away.leagueRecord.wins',
#        'teams.away.leagueRecord.losses', 'teams.away.leagueRecord.pct',
#        'teams.away.score', 'teams.away.team.id', 'teams.away.team.name',
#        'teams.away.team.link', 'teams.away.isWinner', 'teams.away.splitSquad',
#        'teams.away.seriesNumber', 'teams.home.leagueRecord.wins',
#        'teams.home.leagueRecord.losses', 'teams.home.leagueRecord.pct',
#        'teams.home.score', 'teams.home.team.id', 'teams.home.team.name',
#        'teams.home.team.link', 'teams.home.isWinner', 'teams.home.splitSquad',
#        'teams.home.seriesNumber', 'venue.id', 'venue.name', 'venue.link',
#        'content.link', 'gameInfo.attendance', 'gameInfo.firstPitch',
#        'gameInfo.gameDurationMinutes', 'gameInfo.delayDurationMinutes',
#        'rescheduleDate', 'rescheduleGameDate', 'status.reason',
#        'rescheduledFrom', 'rescheduledFromDate', 'description', 'resumeDate',
#        'resumeGameDate', 'resumedFrom', 'resumedFromDate'],
#       dtype='object')

# %%
gbg = sa.generate_gbg_report(att)
gbg
# Out:
# 2022-09-07 08:50:36,120 generate_gbg_report returning report 1952 games
#        officialDate       teams.home.team.name abbreviation  \
# gamePk
# 665272   2022-09-06      Oklahoma City Dodgers          AAA
# 665014   2022-09-06         Round Rock Express          AAA
# 664989   2022-09-06      Sacramento River Cats          AAA
# 666384   2022-09-06       Albuquerque Isotopes          AAA
# 664850   2022-09-06             Salt Lake Bees          AAA
# ...             ...                        ...          ...
# 666070   2022-04-05       Indianapolis Indians          AAA
# 665849   2022-04-05  Jacksonville Jumbo Shrimp          AAA
# 665715   2022-04-05     Lehigh Valley IronPigs          AAA
# 665487   2022-04-05           Nashville Sounds          AAA
# 665604   2022-04-05           Memphis Redbirds          AAA
#
#                  league.name  gameInfo.attendance dayNight dayOfWeek  \
# gamePk
# 665272  Pacific Coast League                 3877    night   Tuesday
# 665014  Pacific Coast League                 3098    night   Tuesday
# 664989  Pacific Coast League                 2210    night   Tuesday
# 666384  Pacific Coast League                 6716    night   Tuesday
# 664850  Pacific Coast League                 4289    night   Tuesday
# ...                      ...                  ...      ...       ...
# 666070  International League                 7724    night   Tuesday
# 665849  International League                 5907    night   Tuesday
# 665715  International League                 7085    night   Tuesday
# 665487  International League                 6136    night   Tuesday
# 665604  International League                 2246    night   Tuesday
#
#             teams.away.team.name  gameInfo.gameDurationMinutes
# gamePk
# 665272           Tacoma Rainiers                         157.0
# 665014  Sugar Land Space Cowboys                         143.0
# 664989        Las Vegas Aviators                         161.0
# 666384        El Paso Chihuahuas                         185.0
# 664850                 Reno Aces                         156.0
# ...                          ...                           ...
# 666070       Omaha Storm Chasers                         185.0
# 665849         Worcester Red Sox                         179.0
# 665715         Columbus Clippers                         203.0
# 665487              Durham Bulls                         215.0
# 665604         Gwinnett Stripers                         162.0
#
# [1952 rows x 9 columns]

# %%
sa.generate_summary_report(att)
# Out:
# 2022-09-07 08:50:36,155 generate_summary_report returning report 30 teams
#                   teams.home.team.name abbreviation           league.name  \
# 342               Albuquerque Isotopes          AAA  Pacific Coast League
# 400                 Las Vegas Aviators          AAA  Pacific Coast League
# 4904                El Paso Chihuahuas          AAA  Pacific Coast League
# 561                     Salt Lake Bees          AAA  Pacific Coast League
# 238              Oklahoma City Dodgers          AAA  Pacific Coast League
# 102                 Round Rock Express          AAA  Pacific Coast League
# 529                    Tacoma Rainiers          AAA  Pacific Coast League
# 105              Sacramento River Cats          AAA  Pacific Coast League
# 2310                         Reno Aces          AAA  Pacific Coast League
# 5434          Sugar Land Space Cowboys          AAA  Pacific Coast League
# 556                   Nashville Sounds          AAA  International League
# 1410            Lehigh Valley IronPigs          AAA  International League
# 445                  Columbus Clippers          AAA  International League
# 484               Indianapolis Indians          AAA  International League
# 494                  Charlotte Knights          AAA  International League
# 533                  Worcester Red Sox          AAA  International League
# 1960                   St. Paul Saints          AAA  International League
# 422                     Buffalo Bisons          AAA  International League
# 234                       Durham Bulls          AAA  International League
# 451                          Iowa Cubs          AAA  International League
# 512                    Toledo Mud Hens          AAA  International League
# 534                Rochester Red Wings          AAA  International League
# 416                    Louisville Bats          AAA  International League
# 568                      Norfolk Tides          AAA  International League
# 564          Jacksonville Jumbo Shrimp          AAA  International League
# 552                      Syracuse Mets          AAA  International League
# 531   Scranton/Wilkes-Barre RailRiders          AAA  International League
# 541                Omaha Storm Chasers          AAA  International League
# 235                   Memphis Redbirds          AAA  International League
# 431                  Gwinnett Stripers          AAA  International League
#
#       num_games  total_att  avg_att  avg_duration
# 342          62     441856     7126           163
# 400          63     433049     6873           172
# 4904         64     433756     6777           173
# 561          64     369507     5773           161
# 238          67     367071     5478           171
# 102          67     365622     5457           167
# 529          69     336392     4875           164
# 105          67     324986     4850           170
# 2310         66     316425     4794           164
# 5434         61     242001     3967           172
# 556          67     510396     7617           161
# 1410         63     470462     7467           171
# 445          64     466724     7292           160
# 484          64     459231     7175           160
# 494          67     476470     7111           161
# 533          69     490706     7111           162
# 1960         68     441046     6485           158
# 422          63     402204     6384           154
# 234          64     399880     6248           166
# 451          66     388641     5888           158
# 512          64     370685     5791           156
# 534          67     387938     5790           160
# 416          64     363052     5672           156
# 568          66     319488     4840           169
# 564          65     303791     4673           151
# 552          61     279722     4585           161
# 531          65     292910     4506           158
# 541          64     253945     3967           161
# 235          65     219349     3374           161
# 431          66     192539     2917           151

# %%
att19 = sa.get_attendance_all_levels(2019)
att19.sample(10)
# Out:
# 2022-09-07 09:02:01,028 get_attendance_sport_id sport_id=11 season=2019;  returning 3137 games
# 2022-09-07 09:02:02,793 get_attendance_sport_id sport_id=12 season=2019;  returning 2142 games
# 2022-09-07 09:02:04,510 get_attendance_sport_id sport_id=13 season=2019;  returning 2097 games
# 2022-09-07 09:02:07,726 get_attendance_sport_id sport_id=14 season=2019;  returning 2126 games
# 2022-09-07 09:02:08,224 get_attendance_sport_id sport_id=23 season=2019;  returning 560 games
# 2022-09-07 09:02:08,239 get_attendance_all_levels season=2019;  returning 10062 games
#                                    link gameType season              gameDate  \
# gamePk
# 572135  /api/v1.1/game/572135/feed/live        R   2019  2019-09-01T17:00:00Z
# 588441  /api/v1.1/game/588441/feed/live        R   2019  2019-06-21T22:30:00Z
# 576417  /api/v1.1/game/576417/feed/live        R   2019  2019-04-23T02:05:00Z
# 575951  /api/v1.1/game/575951/feed/live        R   2019  2019-05-17T22:35:00Z
# 575180  /api/v1.1/game/575180/feed/live        R   2019  2019-06-01T22:35:00Z
# 584706  /api/v1.1/game/584706/feed/live        R   2019  2019-05-02T16:05:00Z
# 580300  /api/v1.1/game/580300/feed/live        R   2019  2019-07-06T00:35:00Z
# 576617  /api/v1.1/game/576617/feed/live        R   2019  2019-04-12T02:05:00Z
# 575515  /api/v1.1/game/575515/feed/live        R   2019  2019-04-21T17:35:00Z
# 574722  /api/v1.1/game/574722/feed/live        R   2019  2019-05-14T23:35:00Z
#
#        officialDate  isTie  gameNumber  publicFacing doubleHeader gamedayType  \
# gamePk
# 572135   2019-09-01  False           1          True            N           Y
# 588441   2019-06-21  False           1          True            N           P
# 576417   2019-04-22  False           1          True            N           Y
# 575951   2019-05-17  False           1          True            N           Y
# 575180   2019-06-01  False           2          True            S           Y
# 584706   2019-05-02  False           1          True            N           Y
# 580300   2019-07-05  False           1          True            N           Y
# 576617   2019-04-11  False           1          True            N           Y
# 575515   2019-04-21  False           1          True            N           Y
# 574722   2019-05-14  False           1          True            N           Y
#
#         ... description rescheduleDate rescheduleGameDate status.reason  \
# gamePk  ...
# 572135  ...         NaN            NaN                NaN           NaN
# 588441  ...         NaN            NaN                NaN           NaN
# 576417  ...         NaN            NaN                NaN           NaN
# 575951  ...         NaN            NaN                NaN           NaN
# 575180  ...         NaN            NaN                NaN           NaN
# 584706  ...         NaN            NaN                NaN           NaN
# 580300  ...         NaN            NaN                NaN           NaN
# 576617  ...         NaN            NaN                NaN           NaN
# 575515  ...         NaN            NaN                NaN           NaN
# 574722  ...         NaN            NaN                NaN           NaN
#
#         rescheduledFrom  rescheduledFromDate  resumeDate  resumeGameDate  \
# gamePk
# 572135              NaN                  NaN         NaN             NaN
# 588441              NaN                  NaN         NaN             NaN
# 576417              NaN                  NaN         NaN             NaN
# 575951              NaN                  NaN         NaN             NaN
# 575180              NaN                  NaN         NaN             NaN
# 584706              NaN                  NaN         NaN             NaN
# 580300              NaN                  NaN         NaN             NaN
# 576617              NaN                  NaN         NaN             NaN
# 575515              NaN                  NaN         NaN             NaN
# 574722              NaN                  NaN         NaN             NaN
#
#         resumedFrom resumedFromDate
# gamePk
# 572135          NaN             NaN
# 588441          NaN             NaN
# 576417          NaN             NaN
# 575951          NaN             NaN
# 575180          NaN             NaN
# 584706          NaN             NaN
# 580300          NaN             NaN
# 576617          NaN             NaN
# 575515          NaN             NaN
# 574722          NaN             NaN
#
# [10 rows x 67 columns]

# %%
att19['gameInfo.gameDurationMinutes'].min()
# Out:
# 40.0

# %%
att19[att19['gameInfo.gameDurationMinutes']<100]
# Out:
#                                    link gameType season              gameDate  \
# gamePk
# 575721  /api/v1.1/game/575721/feed/live        R   2019  2019-04-12T22:35:00Z
# 575234  /api/v1.1/game/575234/feed/live        R   2019  2019-04-24T23:00:00Z
# 575166  /api/v1.1/game/575166/feed/live        R   2019  2019-05-04T22:35:00Z
# 579558  /api/v1.1/game/579558/feed/live        R   2019  2019-05-16T21:43:00Z
# 575671  /api/v1.1/game/575671/feed/live        R   2019  2019-06-02T17:10:00Z
# 575512  /api/v1.1/game/575512/feed/live        R   2019  2019-07-05T22:10:00Z
# 574282  /api/v1.1/game/574282/feed/live        R   2019  2019-04-07T19:35:00Z
# 572278  /api/v1.1/game/572278/feed/live        R   2019  2019-04-13T17:00:00Z
# 571513  /api/v1.1/game/571513/feed/live        R   2019  2019-04-20T17:10:00Z
# 572083  /api/v1.1/game/572083/feed/live        R   2019  2019-05-05T17:00:00Z
# 574439  /api/v1.1/game/574439/feed/live        R   2019  2019-05-11T23:15:00Z
# 574719  /api/v1.1/game/574719/feed/live        R   2019  2019-05-12T00:05:00Z
# 574868  /api/v1.1/game/574868/feed/live        R   2019  2019-06-06T21:00:00Z
# 571681  /api/v1.1/game/571681/feed/live        R   2019  2019-06-24T21:35:00Z
# 574666  /api/v1.1/game/574666/feed/live        R   2019  2019-06-27T22:35:00Z
# 572076  /api/v1.1/game/572076/feed/live        R   2019  2019-07-02T21:05:00Z
# 571760  /api/v1.1/game/571760/feed/live        R   2019  2019-07-06T22:35:00Z
# 574530  /api/v1.1/game/574530/feed/live        R   2019  2019-07-13T23:05:00Z
# 574535  /api/v1.1/game/574535/feed/live        R   2019  2019-07-23T22:05:00Z
# 572333  /api/v1.1/game/572333/feed/live        R   2019  2019-08-01T21:00:00Z
# 571701  /api/v1.1/game/571701/feed/live        R   2019  2019-08-13T21:35:00Z
# 574690  /api/v1.1/game/574690/feed/live        R   2019  2019-08-19T22:05:00Z
# 572710  /api/v1.1/game/572710/feed/live        R   2019  2019-05-01T22:00:00Z
# 572781  /api/v1.1/game/572781/feed/live        R   2019  2019-05-02T20:05:00Z
# 572714  /api/v1.1/game/572714/feed/live        R   2019  2019-05-05T16:00:00Z
# 573019  /api/v1.1/game/573019/feed/live        R   2019  2019-06-30T17:00:00Z
# 573162  /api/v1.1/game/573162/feed/live        R   2019  2019-07-07T16:05:00Z
# 572953  /api/v1.1/game/572953/feed/live        R   2019  2019-07-09T21:00:00Z
# 573019  /api/v1.1/game/573019/feed/live        R   2019  2019-08-02T21:30:00Z
# 572962  /api/v1.1/game/572962/feed/live        R   2019  2019-08-02T22:30:00Z
# 572894  /api/v1.1/game/572894/feed/live        R   2019  2019-08-03T19:00:00Z
# 573036  /api/v1.1/game/573036/feed/live        R   2019  2019-08-07T20:05:00Z
# 572550  /api/v1.1/game/572550/feed/live        R   2019  2019-08-17T20:05:00Z
# 572971  /api/v1.1/game/572971/feed/live        R   2019  2019-08-20T21:00:00Z
# 572692  /api/v1.1/game/572692/feed/live        R   2019  2019-08-28T21:00:00Z
# 577067  /api/v1.1/game/577067/feed/live        R   2019  2019-06-09T17:05:00Z
# 577840  /api/v1.1/game/577840/feed/live        R   2019  2019-06-15T23:35:00Z
# 577777  /api/v1.1/game/577777/feed/live        R   2019  2019-06-30T23:35:00Z
# 574136  /api/v1.1/game/574136/feed/live        R   2019  2019-08-28T16:10:00Z
#
#        officialDate  isTie  gameNumber  publicFacing doubleHeader gamedayType  \
# gamePk
# 575721   2019-04-12  False           1          True            N           Y
# 575234   2019-04-24  False           1          True            N           Y
# 575166   2019-05-04  False           1          True            N           Y
# 579558   2019-05-16  False           2          True            Y           Y
# 575671   2019-06-02  False           2          True            Y           Y
# 575512   2019-07-05  False           2          True            Y           Y
# 574282   2019-04-07  False           1          True            N           Y
# 572278   2019-04-13  False           1          True            N           Y
# 571513   2019-04-20  False           2          True            Y           Y
# 572083   2019-05-05  False           1          True            Y           Y
# 574439   2019-05-11  False           1          True            N           Y
# 574719   2019-05-11  False           1          True            N           Y
# 574868   2019-06-06  False           1          True            Y           Y
# 571681   2019-06-24  False           1          True            N           Y
# 574666   2019-06-27  False           1          True            Y           Y
# 572076   2019-07-02  False           2          True            Y           Y
# 571760   2019-07-06  False           1          True            N           Y
# 574530   2019-07-13  False           1          True            N           Y
# 574535   2019-07-23  False           1          True            Y           Y
# 572333   2019-08-01  False           1          True            Y           Y
# 571701   2019-08-13  False           1          True            Y           Y
# 574690   2019-08-19  False           1          True            Y           Y
# 572710   2019-05-01  False           1          True            N           Y
# 572781   2019-05-02  False           2          True            Y           Y
# 572714   2019-05-05  False           1          True            N           Y
# 573019   2019-06-30  False           1          True            N           Y
# 573162   2019-07-07  False           2          True            Y           Y
# 572953   2019-07-09  False           1          True            Y           Y
# 573019   2019-06-30  False           1          True            N           Y
# 572962   2019-08-02  False           1          True            N           Y
# 572894   2019-08-03  False           1          True            Y           Y
# 573036   2019-08-07  False           2          True            Y           Y
# 572550   2019-08-17  False           2          True            Y           Y
# 572971   2019-08-20  False           1          True            Y           Y
# 572692   2019-08-28  False           1          True            Y           Y
# 577067   2019-06-09  False           1          True            Y           Y
# 577840   2019-06-15  False           1          True            N           Y
# 577777   2019-06-30  False           1          True            N           Y
# 574136   2019-08-28  False           2          True            Y           Y
#
#         ...                                      description rescheduleDate  \
# gamePk  ...
# 575721  ...                                              NaN            NaN
# 575234  ...                                              NaN            NaN
# 575166  ...                                              NaN            NaN
# 579558  ...                               Makeup of 4/10 PPD            NaN
# 575671  ...                                Makeup of 6/1 ppd            NaN
# 575512  ...                               Makeup of 4/18 PPD            NaN
# 574282  ...                                              NaN            NaN
# 572278  ...                                              NaN            NaN
# 571513  ...                               Makeup of 4/19 PPD            NaN
# 572083  ...                                              NaN            NaN
# 574439  ...                                              NaN            NaN
# 574719  ...                                              NaN            NaN
# 574868  ...                                              NaN            NaN
# 571681  ...                                              NaN            NaN
# 574666  ...                                              NaN            NaN
# 572076  ...                                  Makeup 4/20 ppd            NaN
# 571760  ...                                              NaN            NaN
# 574530  ...                                              NaN            NaN
# 574535  ...                                              NaN            NaN
# 572333  ...                                              NaN            NaN
# 571701  ...                                              NaN            NaN
# 574690  ...                                              NaN            NaN
# 572710  ...                                              NaN            NaN
# 572781  ...                                     PPD FROM 5/1            NaN
# 572714  ...                                              NaN            NaN
# 573019  ...                                              NaN            NaN
# 573162  ...                         Makeup of 7/6 PPD (Rain)            NaN
# 572953  ...                                              NaN            NaN
# 573019  ...                                              NaN            NaN
# 572962  ...                                              NaN            NaN
# 572894  ...                                              NaN            NaN
# 573036  ...  Palm Beach home game - Makeup of 8/5 PPD (Rain)            NaN
# 572550  ...                        Makeup of 8/16 PPD (Rain)            NaN
# 572971  ...                                              NaN            NaN
# 572692  ...                                              NaN            NaN
# 577067  ...                                              NaN            NaN
# 577840  ...                                              NaN            NaN
# 577777  ...                                              NaN            NaN
# 574136  ...                        Makeup of 8/27 PPD (Rain)            NaN
#
#        rescheduleGameDate      status.reason       rescheduledFrom  \
# gamePk
# 575721                NaN               Rain                   NaN
# 575234                NaN               Rain                   NaN
# 575166                NaN               Rain                   NaN
# 579558                NaN               Rain  2019-04-10T23:38:00Z
# 575671                NaN                NaN  2019-06-01T23:05:00Z
# 575512                NaN                NaN  2019-04-18T23:05:00Z
# 574282                NaN                NaN                   NaN
# 572278                NaN                NaN                   NaN
# 571513                NaN                NaN  2019-04-19T22:35:00Z
# 572083                NaN                NaN                   NaN
# 574439                NaN               Rain                   NaN
# 574719                NaN               Rain                   NaN
# 574868                NaN                NaN                   NaN
# 571681                NaN                NaN                   NaN
# 574666                NaN                NaN                   NaN
# 572076                NaN                NaN  2019-04-20T17:00:00Z
# 571760                NaN               Rain                   NaN
# 574530                NaN               Rain                   NaN
# 574535                NaN                NaN                   NaN
# 572333                NaN                NaN                   NaN
# 571701                NaN                NaN                   NaN
# 574690                NaN                NaN                   NaN
# 572710                NaN                NaN                   NaN
# 572781                NaN                NaN  2019-05-01T17:00:00Z
# 572714                NaN        Wet Grounds                   NaN
# 573019                NaN                NaN                   NaN
# 573162                NaN                NaN  2019-07-06T22:30:00Z
# 572953                NaN                NaN                   NaN
# 573019                NaN                NaN                   NaN
# 572962                NaN               Rain                   NaN
# 572894                NaN                NaN                   NaN
# 573036                NaN                NaN  2019-08-05T22:30:00Z
# 572550                NaN                NaN  2019-08-16T22:30:00Z
# 572971                NaN                NaN                   NaN
# 572692                NaN                NaN                   NaN
# 577067                NaN                NaN                   NaN
# 577840                NaN               Rain                   NaN
# 577777                NaN  Inclement Weather                   NaN
# 574136                NaN                NaN  2019-08-27T23:05:00Z
#
#         rescheduledFromDate            resumeDate  resumeGameDate  \
# gamePk
# 575721                  NaN                   NaN             NaN
# 575234                  NaN                   NaN             NaN
# 575166                  NaN                   NaN             NaN
# 579558           2019-04-10                   NaN             NaN
# 575671           2019-06-01                   NaN             NaN
# 575512           2019-04-18                   NaN             NaN
# 574282                  NaN                   NaN             NaN
# 572278                  NaN                   NaN             NaN
# 571513           2019-04-19                   NaN             NaN
# 572083                  NaN                   NaN             NaN
# 574439                  NaN                   NaN             NaN
# 574719                  NaN                   NaN             NaN
# 574868                  NaN                   NaN             NaN
# 571681                  NaN                   NaN             NaN
# 574666                  NaN                   NaN             NaN
# 572076           2019-04-20                   NaN             NaN
# 571760                  NaN                   NaN             NaN
# 574530                  NaN                   NaN             NaN
# 574535                  NaN                   NaN             NaN
# 572333                  NaN                   NaN             NaN
# 571701                  NaN                   NaN             NaN
# 574690                  NaN                   NaN             NaN
# 572710                  NaN                   NaN             NaN
# 572781           2019-05-01                   NaN             NaN
# 572714                  NaN                   NaN             NaN
# 573019                  NaN  2019-08-02T21:30:00Z      2019-08-02
# 573162           2019-07-06                   NaN             NaN
# 572953                  NaN                   NaN             NaN
# 573019                  NaN                   NaN             NaN
# 572962                  NaN                   NaN             NaN
# 572894                  NaN                   NaN             NaN
# 573036           2019-08-05                   NaN             NaN
# 572550           2019-08-16                   NaN             NaN
# 572971                  NaN                   NaN             NaN
# 572692                  NaN                   NaN             NaN
# 577067                  NaN                   NaN             NaN
# 577840                  NaN                   NaN             NaN
# 577777                  NaN                   NaN             NaN
# 574136           2019-08-27                   NaN             NaN
#
#                  resumedFrom resumedFromDate
# gamePk
# 575721                   NaN             NaN
# 575234                   NaN             NaN
# 575166                   NaN             NaN
# 579558                   NaN             NaN
# 575671                   NaN             NaN
# 575512                   NaN             NaN
# 574282                   NaN             NaN
# 572278                   NaN             NaN
# 571513                   NaN             NaN
# 572083                   NaN             NaN
# 574439                   NaN             NaN
# 574719                   NaN             NaN
# 574868                   NaN             NaN
# 571681                   NaN             NaN
# 574666                   NaN             NaN
# 572076                   NaN             NaN
# 571760                   NaN             NaN
# 574530                   NaN             NaN
# 574535                   NaN             NaN
# 572333                   NaN             NaN
# 571701                   NaN             NaN
# 574690                   NaN             NaN
# 572710                   NaN             NaN
# 572781                   NaN             NaN
# 572714                   NaN             NaN
# 573019                   NaN             NaN
# 573162                   NaN             NaN
# 572953                   NaN             NaN
# 573019  2019-06-30T17:00:00Z      2019-06-30
# 572962                   NaN             NaN
# 572894                   NaN             NaN
# 573036                   NaN             NaN
# 572550                   NaN             NaN
# 572971                   NaN             NaN
# 572692                   NaN             NaN
# 577067                   NaN             NaN
# 577840                   NaN             NaN
# 577777                   NaN             NaN
# 574136                   NaN             NaN
#
# [39 rows x 67 columns]

# %%
att19[att19['teams.home.team.id']==142]
# Out:
#                                    link gameType season              gameDate  \
# gamePk
# 568145  /api/v1.1/game/568145/feed/live        E   2019  2019-03-25T17:05:00Z
#
#        officialDate  isTie  gameNumber  publicFacing doubleHeader gamedayType  \
# gamePk
# 568145   2019-03-25  False           1          True            N           N
#
#         ...    description rescheduleDate rescheduleGameDate status.reason  \
# gamePk  ...
# 568145  ...  vs. Rochester            NaN                NaN           NaN
#
#         rescheduledFrom  rescheduledFromDate  resumeDate  resumeGameDate  \
# gamePk
# 568145              NaN                  NaN         NaN             NaN
#
#         resumedFrom resumedFromDate
# gamePk
# 568145          NaN             NaN
#
# [1 rows x 67 columns]

# %%
sa.generate_summary_report(att19)
# Out:
# 2022-09-07 09:09:31,222 generate_summary_report returning report 134 teams
#        teams.home.team.name abbreviation           league.name  num_games  \
# 142         Minnesota Twins          MLB       American League          1
# 400      Las Vegas Aviators          AAA  Pacific Coast League         73
# 102      Round Rock Express          AAA  Pacific Coast League         73
# 342    Albuquerque Isotopes          AAA  Pacific Coast League         72
# 105   Sacramento River Cats          AAA  Pacific Coast League         75
# ...                     ...          ...                   ...        ...
# 5435        York Revolution          IND       Atlantic League         70
# 5431     High Point Rockers          IND       Atlantic League         70
# 525     West Virginia Power          IND       Atlantic League         70
# 567         Trenton Thunder      College      MLB Draft League         75
# 493          Frederick Keys      College      MLB Draft League         71
#
#       total_att  avg_att  avg_duration
# 142        3567     3567           165
# 400      671397     9197           185
# 102      610048     8356           187
# 342      563090     7820           183
# 105      572897     7638           185
# ...         ...      ...           ...
# 5435     199047     2843           180
# 5431     144487     2064           160
# 525      118446     1692           165
# 567      367447     4899           156
# 493      266386     3751           169
#
# [134 rows x 7 columns]
